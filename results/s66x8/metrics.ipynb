# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Load Data 
file_path_resff = "resff-s66.csv"
df_resff = pd.read_csv(file_path_resff)

file_path_mace = "mace-s66.csv"
df_mace = pd.read_csv(file_path_mace)

file_path_esp = "esp0.3-s66.csv"
df_esp = pd.read_csv(file_path_esp)

file_path_open = "openff-s66.csv"
df_openff = pd.read_csv(file_path_open)

methods = {
    "ResFF": (df_resff, "wb97m_relative_energy", "resff_relative_energy"),
    "MACE": (df_mace, "wb97m_relative_energy", "MACE_relative_energy"),
    "Espaloma": (df_esp, "ccsd(t)_relative_energy", "mm_relative_energy"),
    "OpenFF": (df_openff, "ccsd(t)_relative_energy", "mm_relative_energy")
}

results = []

# Compute Metrics for All Methods
for name, (df, ref_col, pred_col) in methods.items():

    clean_df = df[[ref_col, pred_col]].dropna()
    
    y_true = clean_df[ref_col]
    y_pred = clean_df[pred_col]
    
    # Calculate RMSE, MAE, and Pearson Correlation (r)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    correlation = np.corrcoef(y_true, y_pred)[0, 1]
    r2 = r2_score(y_true, y_pred)

    results.append({
        "Method": name,
        "RMSE (kcal/mol)": rmse,
        "MAE (kcal/mol)": mae,
        "Correlation (r)": correlation,
        'R² Score': r2
    })

df_summary = pd.DataFrame(results)

print("\n--- Summary of S66x8 Benchmarks ---")
print(df_summary.to_string(index=False, float_format=lambda x: f"{x:.4f}"))
# Out:
# --- Summary of S66x8 Benchmarks ---
#   Method  RMSE (kcal/mol)  MAE (kcal/mol)  Correlation (r)  R² Score
#    ResFF           0.5519          0.3941           0.9701    0.9288
#     MACE           0.6206          0.3651           0.9746    0.9099
#     GAFF           2.0304          1.0632           0.6805    0.0389
# Espaloma           1.3932          0.7425           0.8057    0.5332
#   OpenFF           1.4952          0.8714           0.7930    0.4788
